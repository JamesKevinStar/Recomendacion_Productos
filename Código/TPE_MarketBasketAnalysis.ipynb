# %% [markdown]
# # 1. Importar Librerías

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# # 2. Trabajar con la Base de Datos

# %% [markdown]
# ## A. Conectar con la DB

# %%
# Conectar a la base de datos SQLite
conexion = sqlite3.connect("sanoyfresco.db")

# %% [markdown]
# ## B. Obtener Valores de la DB

# %%
# Cargar una tabla completa en un DataFrame
df = pd.read_sql_query("SELECT * FROM tickets", conexion)

# Mostrar los primeros registros del DataFrame
df.head(5)
# Out:
#    id_pedido  id_cliente                fecha  hora  id_departamento  \
# 0          1      112108  2023-02-02 00:00:00    10                4
# 1          1      112108  2023-02-02 00:00:00    10                4
# 2          1      112108  2023-02-02 00:00:00    10                4
# 3          2      202279  2023-02-03 00:00:00     9                4
# 4          2      202279  2023-02-03 00:00:00     9                4
#
#    id_seccion  id_producto                  nombre_producto  precio_unitario  \
# 0          83        49683                     Pepino Kirby             0.99
# 1          24        13176       Bolsa de Bananas Orgánicas             2.45
# 2          24        47209           Aguacate Hass Orgánico             1.79
# 3          83        28985  Col Rizada Orgánica de Michigan             2.55
# 4          83        17794                       Zanahorias             0.95
#
#    cantidad  precio_total
# 0         4          3.96
# 1         4          9.80
# 2         2          3.58
# 3         2          5.10
# 4         5          4.75

# %%
# Cerrar la conexión a la base de datos
conexion.close()

# %% [markdown]
# # 3. Información de los Datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4975718 entries, 0 to 4975717
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   id_pedido        int64
#  1   id_cliente       int64
#  2   fecha            object
#  3   hora             int64
#  4   id_departamento  int64
#  5   id_seccion       int64
#  6   id_producto      int64
#  7   nombre_producto  object
#  8   precio_unitario  float64
#  9   cantidad         int64
#  10  precio_total     float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 417.6+ MB

# %% [markdown]
# La fecha no está en formato correcto

# %%
df["fecha"] = pd.to_datetime(df["fecha"])

# %% [markdown]
# # 4. Crear Nuevos Valores

# %%
df_cesta = df[["id_pedido", "nombre_producto"]]
df_cesta.head(5)
# Out:
#    id_pedido                  nombre_producto
# 0          1                     Pepino Kirby
# 1          1       Bolsa de Bananas Orgánicas
# 2          1           Aguacate Hass Orgánico
# 3          2  Col Rizada Orgánica de Michigan
# 4          2                       Zanahorias

# %%
# Agrupar los productos por id_pedido, separarlos por ","
df_agrupado = df_cesta.groupby("id_pedido")["nombre_producto"].apply(lambda producto: ",".join(producto))
df_agrupado.head(5)
# Out:
# id_pedido
# 1     Pepino Kirby,Bolsa de Bananas Orgánicas,Aguaca...
# 2            Col Rizada Orgánica de Michigan,Zanahorias
# 3                              Espinacas Baby Orgánicas
# 5     Bolsa de Bananas Orgánicas,Frambuesas Orgánica...
# 10    Banana,Cilantro Orgánico,Aguacate Orgánico,Ceb...
# Name: nombre_producto, dtype: object

# %%
# Aplicar pd.get_dummies() para transformar los productos en columnas con 0 o 1
df_transacciones = df_agrupado.str.get_dummies(sep=",")
df_transacciones.head(10)
# Out:
#            Agua con Gas de Pomelo  Aguacate Hass Orgánico  Aguacate Orgánico  \
# id_pedido
# 1                               0                       1                  0
# 2                               0                       0                  0
# 3                               0                       0                  0
# 5                               0                       1                  0
# 10                              0                       0                  1
# 14                              0                       0                  0
# 18                              1                       0                  1
# 19                              0                       0                  0
# 20                              0                       0                  0
# 22                              0                       0                  0
#
#            Ajo Orgánico  Apio Orgánico en Ramillete Pequeño  \
# id_pedido
# 1                     0                                   0
# 2                     0                                   0
# 3                     0                                   0
# 5                     0                                   0
# 10                    0                                   0
# 14                    0                                   0
# 18                    0                                   0
# 19                    0                                   0
# 20                    0                                   0
# 22                    0                                   0
#
#            Arándanos Orgánicos  Banana  Bolsa de Bananas Orgánicas  \
# id_pedido
# 1                            0       0                           1
# 2                            0       0                           0
# 3                            0       0                           0
# 5                            0       0                           1
# 10                           0       1                           0
# 14                           0       0                           0
# 18                           0       0                           0
# 19                           0       0                           0
# 20                           0       1                           0
# 22                           0       1                           0
#
#            Calabacín Orgánico  Cebolla Amarilla Orgánica  ...  \
# id_pedido                                                 ...
# 1                           0                          0  ...
# 2                           0                          0  ...
# 3                           0                          0  ...
# 5                           0                          0  ...
# 10                          0                          0  ...
# 14                          0                          0  ...
# 18                          0                          0  ...
# 19                          0                          0  ...
# 20                          0                          0  ...
# 22                          0                          0  ...
#
#            Manzana Honeycrisp Orgánica  Manzanas Gala Orgánicas  Pepino Kirby  \
# id_pedido
# 1                                    0                        0             1
# 2                                    0                        0             0
# 3                                    0                        0             0
# 5                                    0                        0             0
# 10                                   0                        0             0
# 14                                   0                        0             0
# 18                                   0                        0             0
# 19                                   0                        0             0
# 20                                   0                        0             0
# 22                                   0                        0             0
#
#            Pepino Orgánico  Racimo de Tomates Orgánicos  Rúcula Baby Orgánica  \
# id_pedido
# 1                        0                            0                     0
# 2                        0                            0                     0
# 3                        0                            0                     0
# 5                        0                            0                     0
# 10                       0                            0                     0
# 14                       0                            0                     0
# 18                       0                            0                     0
# 19                       0                            0                     0
# 20                       0                            0                     0
# 22                       0                            0                     0
#
#            Tomates Cherry Orgánicos  Uvas Rojas sin Semillas  Zanahorias  \
# id_pedido
# 1                                 0                        0           0
# 2                                 0                        0           1
# 3                                 0                        0           0
# 5                                 0                        0           0
# 10                                0                        0           0
# 14                                0                        0           0
# 18                                0                        0           0
# 19                                0                        0           0
# 20                                0                        0           0
# 22                                0                        0           0
#
#            Zanahorias Baby Orgánicas
# id_pedido
# 1                                  0
# 2                                  0
# 3                                  0
# 5                                  0
# 10                                 0
# 14                                 0
# 18                                 0
# 19                                 1
# 20                                 0
# 22                                 0
#
# [10 rows x 40 columns]

# %% [markdown]
# # 5. Obtener Métricas

# %% [markdown]
# ## A. Soporte

# %%
# Soporte para cada producto
soporte = df_transacciones.mean() * 100
soporte.sort_values(ascending=False)
# Out:
# Banana                                23.809381
# Bolsa de Bananas Orgánicas            19.129710
# Fresas Orgánicas                      13.349170
# Espinacas Baby Orgánicas              12.198935
# Aguacate Hass Orgánico                10.703004
# Aguacate Orgánico                      8.929331
# Limón Grande                           7.791279
# Fresas                                 7.241960
# Limones                                7.107944
# Leche Entera Orgánica                  6.918301
# Frambuesas Orgánicas                   6.906797
# Cebolla Amarilla Orgánica              5.706324
# Ajo Orgánico                           5.521778
# Calabacín Orgánico                     5.302429
# Arándanos Orgánicos                    5.086138
# Pepino Kirby                           4.840044
# Manzana Fuji Orgánica                  4.502841
# Limón Orgánico                         4.422266
# Tomates Cherry Orgánicos               4.266795
# Manzana Honeycrisp Orgánica            4.231216
# Uvas Rojas sin Semillas                4.200733
# Pepino Orgánico                        4.114091
# Manzana Honeycrisp                     4.036476
# Zanahorias Baby Orgánicas              3.898528
# Agua con Gas de Pomelo                 3.839504
# Crema Orgánica                         3.827855
# Manzana Fuji Extra Grande Orgánica     3.780189
# Cebollas Amarillas                     3.728592
# Rúcula Baby Orgánica                   3.671849
# Manzanas Gala Orgánicas                3.665442
# Zanahorias                             3.647386
# Coliflor Fresca                        3.597876
# Hummus Original                        3.593798
# Cilantro Orgánico                      3.538900
# Crema                                  3.470606
# Espárragos                             3.446724
# Cebolla Roja Orgánica                  3.429687
# Apio Orgánico en Ramillete Pequeño     3.427891
# Col Rizada Orgánica de Michigan        3.396632
# Racimo de Tomates Orgánicos            3.239267
# dtype: float64

# %% [markdown]
# ## B. Confianza

# %%
# Función para calcular la confianza entre dos productos en la muestra
def confianza(antecedente, consecuente):
    # Casos donde se compraron ambos productos
    conjunto_ac = df_transacciones[(df_transacciones[antecedente] == 1) & (df_transacciones[consecuente] == 1)]

    # Confianza = compras conjuntas / compras de producto A
    return len(conjunto_ac) / df_transacciones[antecedente].sum()

# %% [markdown]
# ## C. Lift

# %%
# Función para calcular el lift entre dos productos en la muestra
def lift(antecedente, consecuente):
    soporte_a = df_transacciones[antecedente].mean()
    soporte_c = df_transacciones[consecuente].mean()
    conteo_ac = len(df_transacciones[(df_transacciones[antecedente] == 1) &
                                   (df_transacciones[consecuente] == 1)])
    soporte_ac = conteo_ac / len(df_transacciones)
    return soporte_ac / (soporte_a * soporte_c)

# %% [markdown]
# # 6. Calcular Métricas para los Productos

# %%
from itertools import combinations

# Definir un umbral para la confianza mínima
umbral_confianza = 0.05

asociaciones = []

# Generar combinaciones de productos y calcular confianza y lift
for antecedente, consecuente in combinations(df_transacciones.columns, 2):

    # Soporte del antecedente
    soporte_a = df_transacciones[antecedente].mean()

    # Calcular confianza
    conf = confianza(antecedente, consecuente)
    if conf > umbral_confianza:
        asociaciones.append({
            "antecedente": antecedente,
            "consecuente": consecuente,
            "soporte_a": round(soporte_a * 100,1),
            "confianza": round(conf * 100,1),
            "lift": round(lift(antecedente, consecuente),1)
        })


# Convertir las asociaciones en un DataFrame
df_asociaciones = pd.DataFrame(asociaciones)

# Ordenar las asociaciones por confianza de mayor a menor
df_asociaciones.sort_values(by = "lift", ascending = False, inplace = True)

df_asociaciones.head(10)
# Out:
#                             antecedente                      consecuente  \
# 185               Cebolla Roja Orgánica                Cilantro Orgánico
# 224                   Cilantro Orgánico                          Limones
# 61                         Ajo Orgánico        Cebolla Amarilla Orgánica
# 106  Apio Orgánico en Ramillete Pequeño                       Zanahorias
# 102  Apio Orgánico en Ramillete Pequeño                  Pepino Orgánico
# 85   Apio Orgánico en Ramillete Pequeño        Cebolla Amarilla Orgánica
# 62                         Ajo Orgánico            Cebolla Roja Orgánica
# 89   Apio Orgánico en Ramillete Pequeño  Col Rizada Orgánica de Michigan
# 346                     Hummus Original        Zanahorias Baby Orgánicas
# 349                             Limones                     Limón Grande
#
#      soporte_a  confianza  lift
# 185        3.4       12.8   3.6
# 224        3.5       25.4   3.6
# 61         5.5       20.1   3.5
# 106        3.4       12.0   3.3
# 102        3.4       12.7   3.1
# 85         3.4       16.2   2.8
# 62         5.5        9.2   2.7
# 89         3.4        8.9   2.6
# 346        3.6        9.8   2.5
# 349        7.1       19.8   2.5

# %% [markdown]
# # 7. Obtener Tabla Final

# %% [markdown]
# ## A. Valores Únicos

# %% [markdown]
# Generamos una tabla de los productos únicos con su 'id_producto', 'id_seccion', 'id_departamento' para enriquecer la tabla de reglas

# %%
# Crear una tabla con los productos únicos y las columnas correspondientes
productos_unicos = df[["id_producto", "id_seccion", "id_departamento", "nombre_producto"]].drop_duplicates()

productos_unicos
# Out:
#      id_producto  id_seccion  id_departamento  \
# 0          49683          83                4
# 1          13176          24                4
# 2          47209          24                4
# 3          28985          83                4
# 4          17794          83                4
# 5          21903         123                4
# 7          27966         123                4
# 9          24852          24                4
# 10         31717          16                4
# 11         47766          24                4
# 12          4605          83                4
# 13         21137          24                4
# 14         49235          53               16
# 15         27845          84               16
# 16         45066          24                4
# 17         44632         115                7
# 19         46979          83                4
# 21         42265         123                4
# 26          8518          83                4
# 34         41950          83                4
# 35         47626          24                4
# 38         22935          83                4
# 41          4920         123                4
# 47         21616         123                4
# 49         28204          24                4
# 52         16797          24                4
# 53         39275         123                4
# 57         37646          24                4
# 59         40706         123                4
# 60          5876          24                4
# 67         30391          83                4
# 70         24964          83                4
# 75         19057          24                4
# 85         26209          24                4
# 99          8277          24                4
# 138        27104          83                4
# 156        30489          67               20
# 159        44359          83                4
# 172        45007          83                4
# 289        27086          53               16
#
#                         nombre_producto
# 0                          Pepino Kirby
# 1            Bolsa de Bananas Orgánicas
# 2                Aguacate Hass Orgánico
# 3       Col Rizada Orgánica de Michigan
# 4                            Zanahorias
# 5              Espinacas Baby Orgánicas
# 7                  Frambuesas Orgánicas
# 9                                Banana
# 10                    Cilantro Orgánico
# 11                    Aguacate Orgánico
# 12                   Cebollas Amarillas
# 13                     Fresas Orgánicas
# 14                       Crema Orgánica
# 15                Leche Entera Orgánica
# 16                   Manzana Honeycrisp
# 17               Agua con Gas de Pomelo
# 19                           Espárragos
# 21            Zanahorias Baby Orgánicas
# 26                Cebolla Roja Orgánica
# 34          Racimo de Tomates Orgánicos
# 35                         Limón Grande
# 38            Cebolla Amarilla Orgánica
# 41              Uvas Rojas sin Semillas
# 47                 Rúcula Baby Orgánica
# 49                Manzana Fuji Orgánica
# 52                               Fresas
# 53                  Arándanos Orgánicos
# 57              Manzanas Gala Orgánicas
# 59             Tomates Cherry Orgánicos
# 60                       Limón Orgánico
# 67                      Pepino Orgánico
# 70                         Ajo Orgánico
# 75   Manzana Fuji Extra Grande Orgánica
# 85                              Limones
# 99          Manzana Honeycrisp Orgánica
# 138                     Coliflor Fresca
# 156                     Hummus Original
# 159  Apio Orgánico en Ramillete Pequeño
# 172                  Calabacín Orgánico
# 289                               Crema

# %% [markdown]
# ## B. Juntar Datos

# %%
df_asociaciones_enriquecido = df_asociaciones.merge(productos_unicos, left_on = "antecedente", right_on = "nombre_producto", how = "left").drop(columns=["nombre_producto"])
df_asociaciones_enriquecido.columns = ["antecedente", "consecuente", "soporte_a", "confianza", "lift", "id_producto_a", "id_seccion_a", "id_departamento_a"]
df_asociaciones_enriquecido.head(10)
# Out:
#                           antecedente                      consecuente  \
# 0               Cebolla Roja Orgánica                Cilantro Orgánico
# 1                   Cilantro Orgánico                          Limones
# 2                        Ajo Orgánico        Cebolla Amarilla Orgánica
# 3  Apio Orgánico en Ramillete Pequeño                       Zanahorias
# 4  Apio Orgánico en Ramillete Pequeño                  Pepino Orgánico
# 5  Apio Orgánico en Ramillete Pequeño        Cebolla Amarilla Orgánica
# 6                        Ajo Orgánico            Cebolla Roja Orgánica
# 7  Apio Orgánico en Ramillete Pequeño  Col Rizada Orgánica de Michigan
# 8                     Hummus Original        Zanahorias Baby Orgánicas
# 9                             Limones                     Limón Grande
#
#    soporte_a  confianza  lift  id_producto_a  id_seccion_a  id_departamento_a
# 0        3.4       12.8   3.6           8518            83                  4
# 1        3.5       25.4   3.6          31717            16                  4
# 2        5.5       20.1   3.5          24964            83                  4
# 3        3.4       12.0   3.3          44359            83                  4
# 4        3.4       12.7   3.1          44359            83                  4
# 5        3.4       16.2   2.8          44359            83                  4
# 6        5.5        9.2   2.7          24964            83                  4
# 7        3.4        8.9   2.6          44359            83                  4
# 8        3.6        9.8   2.5          30489            67                 20
# 9        7.1       19.8   2.5          26209            24                  4

# %% [markdown]
# ## C. Exportar DataFrame

# %%
df_asociaciones_enriquecido.to_csv("reglas.csv", index = False, sep = ";", decimal = ",")
